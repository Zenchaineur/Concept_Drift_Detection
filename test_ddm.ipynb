# %%
from DDM import *
from dataset import *
import matplotlib.pyplot as plt

# %%
X, y, targets = dataset('datasets/ELEC.csv')
pm = PredictionManager(X, y, targets)
error_rate_list, nb_errors = pm.run_all_steps()
print("Error rate :", nb_errors/len(X))
print("Accuracy :", 100*(1-nb_errors/len(X)))
plt.plot(error_rate_list, color = 'blue')
plt.show()
# Out:
# Error rate : 0.28668535234269826
# Accuracy : 71.33146476573017

# %%
X, y, targets = dataset('datasets/COVTYPE.csv')
pm = PredictionManager(X, y, targets)
error_rate_list, nb_errors = pm.run_all_steps()
print("Error rate :", nb_errors/len(X))
print("Accuracy :", 100*(1-nb_errors/len(X)))
plt.plot(error_rate_list, color = 'blue')
plt.show()
# Out:
# Error rate : 0.22989065611494447
# Accuracy : 77.01093438850555

# %%
X, y, targets = dataset('datasets/POKERHAND.csv')
pm = PredictionManager(X, y, targets)
error_rate_list, nb_errors = pm.run_all_steps()
print("Error rate :", nb_errors/len(X))
print("Accuracy :", 100*(1-nb_errors/len(X)))
plt.plot(error_rate_list, color = 'blue')
plt.show()
# Out:
# Error rate : 0.4607314607314607
# Accuracy : 53.92685392685392

# %%
X, y, targets = dataset('datasets/RIALTO.csv')
pm = PredictionManager(X, y, targets)
error_rate_list, nb_errors = pm.run_all_steps()
print("Error rate :", nb_errors/len(X))
print("Accuracy :", 100*(1-nb_errors/len(X)))
plt.plot(error_rate_list, color = 'blue')
plt.show()
# Out:
# Error rate : 0.5811985556055392
# Accuracy : 41.88014443944608

# %%
X, y, targets = dataset('datasets/ROTATINGHYPERPLANE.csv')
pm = PredictionManager(X, y, targets)
error_rate_list, nb_errors = pm.run_all_steps()
print("Error rate :", nb_errors/len(X))
print("Accuracy :", 100*(1-nb_errors/len(X)))
plt.plot(error_rate_list, color = 'blue')
plt.show()
# Out:
# Error rate : 0.09105545527727639
# Accuracy : 90.89445447227236

# %%
X, y, targets = dataset('datasets/MOVINGSQUARES.csv')
pm = PredictionManager(X, y, targets)
error_rate_list, nb_errors = pm.run_all_steps()
print("Error rate :", nb_errors/len(X))
print("Accuracy :", 100*(1-nb_errors/len(X)))
plt.plot(error_rate_list, color = 'blue')
plt.show()
# Out:
# Error rate : 0.007020035100175501
# Accuracy : 99.29799648998245

# %%
X, y, targets = dataset('datasets/MOVINGRBF.csv')
pm = PredictionManager(X, y, targets)
error_rate_list, nb_errors = pm.run_all_steps()
print("Error rate :", nb_errors/len(X))
print("Accuracy :", 100*(1-nb_errors/len(X)))
plt.plot(error_rate_list, color = 'blue')
plt.show()
# Out:
# Error rate : 0.4971274856374282
# Accuracy : 50.287251436257186

# %%
X, y, targets = dataset('datasets/INTERCHANGINGRBF.csv')
pm = PredictionManager(X, y, targets)
error_rate_list, nb_errors = pm.run_all_steps()
print("Error rate :", nb_errors/len(X))
print("Accuracy :", 100*(1-nb_errors/len(X)))
plt.plot(error_rate_list, color = 'blue')
plt.show()
# Out:
# Error rate : 0.3263116315581578
# Accuracy : 67.36883684418422
